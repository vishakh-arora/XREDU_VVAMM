# %% [markdown]
# Dataset Description: This dataset contains the number of calories burned by a person while performing some activity/exercise.
# It currently contains 248 activities and exercises ranging from running, cycling, calisthenics, etc.
# Data Source: https://www.kaggle.com/aadhavvignesh/calories-burned-during-exercise-and-activities

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("exercise_dataset.csv")
df
# Out:
#         Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 0                Cycling, mountain bike, bmx     502     598     695     791
# 1        Cycling, <10 mph, leisure bicycling     236     281     327     372
# 2                   Cycling, >20 mph, racing     944    1126    1308    1489
# 3                Cycling, 10-11.9 mph, light     354     422     490     558
# 4             Cycling, 12-13.9 mph, moderate     472     563     654     745
# ..                                       ...     ...     ...     ...     ...
# 243                         General cleaning     207     246     286     326
# 244                        Cleaning, dusting     148     176     204     233
# 245                         Taking out trash     177     211     245     279
# 246            Walking, pushing a wheelchair     236     281     327     372
# 247  Teach physical education,exercise class     236     281     327     372
#
#      Calories per kg
# 0           1.750730
# ...

# %%
#exercises that burn the most calories
highest_cal = df.sort_values('Calories per kg', ascending=False).head()
highest_cal
# Out:
#     Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 47      Running, 10.9 mph (5.5 min mile)    1062    1267    1471    1675
# 217         Cross country skiing, uphill     974    1161    1348    1536
# 46          Running, 10 mph (6 min mile)     944    1126    1308    1489
# 2               Cycling, >20 mph, racing     944    1126    1308    1489
# 188                    Skin diving, fast     944    1126    1308    1489
#
#      Calories per kg
# 47          3.706591
# 217         3.397878
# 46          3.294974
# 2           3.294974
# 188         3.294974

# %%
plt.figure(figsize=(15,5))
plt.bar(highest_cal["Activity, Exercise or Sport (1 hour)"], highest_cal["Calories per kg"])
plt.xlabel("Exercise")
plt.ylabel("Calories burned per kg")
plt.title("Bar graph for calories per kg for the highest burning exercises")

plt.show()

# %%
#exercises that burn the least calories
lowest_cal = df.sort_values('Calories per kg', ascending=True).head()
lowest_cal
# Out:
#     Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 238              Watering lawn or garden      89     106     123     140
# 166    Walking, under 2.0 mph, very slow     118     141     163     186
# 167                Walking 2.0 mph, slow     148     176     204     233
# 70                               Croquet     148     176     204     233
# 63                             Billiards     148     176     204     233
#
#      Calories per kg
# 238         0.310067
# 166         0.411618
# 167         0.515199
# 70          0.515199
# 63          0.515199

# %%
plt.figure(figsize=(15,5))
plt.bar(lowest_cal["Activity, Exercise or Sport (1 hour)"], highest_cal["Calories per kg"])
plt.xlabel("Exercise")
plt.ylabel("Calories burned per kg")
plt.title("Bar graph for calories per kg for the lowest burning exercises")

plt.show()

# %%
combined_df = lowest_cal.head(3).append(highest_cal.head(3))
combined_df
# Out:
#     Activity, Exercise or Sport (1 hour)  130 lb  155 lb  180 lb  205 lb  \
# 238              Watering lawn or garden      89     106     123     140
# 166    Walking, under 2.0 mph, very slow     118     141     163     186
# 167                Walking 2.0 mph, slow     148     176     204     233
# 47      Running, 10.9 mph (5.5 min mile)    1062    1267    1471    1675
# 217         Cross country skiing, uphill     974    1161    1348    1536
# 46          Running, 10 mph (6 min mile)     944    1126    1308    1489
#
#      Calories per kg
# 238         0.310067
# 166         0.411618
# 167         0.515199
# 47          3.706591
# 217         3.397878
# 46          3.294974

# %%
plt.figure(figsize=(20,5))
plt.bar(combined_df["Activity, Exercise or Sport (1 hour)"], combined_df["Calories per kg"])
plt.xlabel("Exercise")
plt.ylabel("Calories burned per kg")
plt.title("Bar graph for calories per kg for the lowest and highest burning exercises")

plt.show()
